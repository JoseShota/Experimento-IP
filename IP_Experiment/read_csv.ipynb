# %% [markdown]
# # actual_exp_phase_1
# Script para analizar los csv que genera oTree con los datos del de prueba.
#
# actualmente con "otree test experiment --export=bot_data.csv" debe generar los datos

# %%
import pandas as pd

# %%
all_apps = pd.read_csv('bot_stage_1/all_apps_wide.csv')
payment = pd.read_csv('bot_stage_1/payment.csv')
personal_info = pd.read_csv('bot_stage_1/personal_info.csv')
stage_1 = pd.read_csv('bot_stage_1/stage_1.csv')
stage_2 = pd.read_csv('bot_stage_1/stage_2.csv')
# Out:
# /var/folders/wv/n9lffh7n44scbybpz22gdvh80000gn/T/ipykernel_12388/3628258833.py:1: DtypeWarning: Columns (89,102,115,128,141,154,167,180,193,206,219,232,245,258,271,284,297,310,323,336,349,362,375,388,401,414,427,440,453,466,479,492,505,518,531,544,557,570,583,596,609,622,635,648,661,674,687,700,713,726,739,752,765,778,791,804,817,830,843,856,869,882,895,908,921,934,947,960,973,986,999,1012,1025,1038,1051,1064,1077,1090,1103,1116,1129,1142,1155,1168,1181,1194,1207,1223,1224,1232,1241,1250,1259,1268,1277,1286,1295,1304,1313,1322) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_apps = pd.read_csv('bot_stage_1/all_apps_wide.csv')

# %%
last_session_code = (
    all_apps
    .sort_values(by='participant.time_started_utc',ascending=False)
    ['session.code']
    .values
    [0]
)

# %%
all_apps[all_apps['session.code'] == last_session_code]
# Out:
#      participant.id_in_session participant.code  participant.label  \
# 673                          1         9zikkunp                NaN
# 674                          2         39j572uf                NaN
# 675                          3         e1bfors3                NaN
# 676                          4         u7y0pqi0                NaN
# 677                          5         30z925i3                NaN
# 678                          6         998l2xa3                NaN
# 679                          7         xcubwv90                NaN
# 680                          8         imt6s7pm                NaN
# 681                          9         iqsdo7bi                NaN
# 682                         10         byy1e2n7                NaN
# 683                         11         j5ywtbw0                NaN
# 684                         12         3e2cdsl1                NaN
# 685                         13         2dj39gc0                NaN
# ...

# %%
personal_info[personal_info['session.code'] == last_session_code]
# Out:
#     participant.id_in_session participant.code  participant.label  \
# 0                           1         9zikkunp                NaN
# 1                           2         39j572uf                NaN
# 2                           3         e1bfors3                NaN
# 3                           4         u7y0pqi0                NaN
# 4                           5         30z925i3                NaN
# 5                           6         998l2xa3                NaN
# 6                           7         xcubwv90                NaN
# 7                           8         imt6s7pm                NaN
# 8                           9         iqsdo7bi                NaN
# 9                          10         byy1e2n7                NaN
# 10                         11         j5ywtbw0                NaN
# 11                         12         3e2cdsl1                NaN
# 12                         13         2dj39gc0                NaN
# ...

# %%
stage_1[stage_1['session.code'] == last_session_code]
# Out:
#      participant.id_in_session participant.code  participant.label  \
# 0                            1         9zikkunp                NaN
# 1                            2         39j572uf                NaN
# 2                            3         e1bfors3                NaN
# 3                            4         u7y0pqi0                NaN
# 4                            5         30z925i3                NaN
# ..                         ...              ...                ...
# 160                         11         j5ywtbw0                NaN
# 161                         12         3e2cdsl1                NaN
# 162                         13         2dj39gc0                NaN
# 163                         14         lmbgigtx                NaN
# 164                         15         nburqiwz                NaN
#
#      participant._is_bot  participant._index_in_pages  \
# 0                      1                          855
# ...

# %%
stage_2[stage_2['session.code'] == last_session_code]
# Out:
#        participant.id_in_session participant.code  participant.label  \
# 56875                          1         9zikkunp                NaN
# 56876                          2         39j572uf                NaN
# 56877                          3         e1bfors3                NaN
# 56878                          4         u7y0pqi0                NaN
# 56879                          5         30z925i3                NaN
# ...                          ...              ...                ...
# 58235                         11         j5ywtbw0                NaN
# 58236                         12         3e2cdsl1                NaN
# 58237                         13         2dj39gc0                NaN
# 58238                         14         lmbgigtx                NaN
# 58239                         15         nburqiwz                NaN
#
#        participant._is_bot  participant._index_in_pages  \
# 56875                    1                          855
# ...

# %%
# Display relevant columns for stage 2
(
    stage_2
    [stage_2['session.code']==last_session_code]
    [['participant.id_in_session', 'participant.code',
       'participant._is_bot', 'participant._current_app_name',
       'participant.payoff', 'player.payoff',
       'player.id_in_group',
       'player.topic_idx', 'player.treatment_idx',
       'subsession.round_number', 'session.code']]
    .sort_values(by=['subsession.round_number', 'participant.id_in_session'])
)
# Out:
#        participant.id_in_session participant.code  participant._is_bot  \
# 56875                          1         9zikkunp                    1
# 56876                          2         39j572uf                    1
# 56877                          3         e1bfors3                    1
# 56878                          4         u7y0pqi0                    1
# 56879                          5         30z925i3                    1
# ...                          ...              ...                  ...
# 58235                         11         j5ywtbw0                    1
# 58236                         12         3e2cdsl1                    1
# 58237                         13         2dj39gc0                    1
# 58238                         14         lmbgigtx                    1
# 58239                         15         nburqiwz                    1
#
#       participant._current_app_name  participant.payoff  player.payoff  \
# ...
